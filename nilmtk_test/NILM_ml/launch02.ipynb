# %%
from train import train
train()
# Out:
# Starting training...
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# Starting training for fridge
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# time window: 5
# LinearRegression
# RandomForestRegressor
# GradientBoostingRegressor
# SVR
# LogisticRegression
# RandomForestClassifier
# GradientBoostingClassifier
# SVC
#  25%|█████████████████████                                                               | 1/4 [01:19<03:57, 79.21s/it]
# time window: 10
# LinearRegression
# RandomForestRegressor
# GradientBoostingRegressor
# SVR
# LogisticRegression
# RandomForestClassifier
# GradientBoostingClassifier
# SVC
#  50%|██████████████████████████████████████████                                          | 2/4 [02:58<03:01, 90.76s/it]
# time window: 15
# LinearRegression
# RandomForestRegressor
# GradientBoostingRegressor
# SVR
# ...
